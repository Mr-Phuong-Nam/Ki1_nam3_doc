# %%
import requests
import json

def get_data():
    url = 'https://api.fbi.gov/wanted/v1/list'
    data = requests.get(url).json()
    return data


data = get_data()

import pandas as pd
df = pd.DataFrame(data['items'])

df
# Link: https://api.fbi.gov/docs
# There is no description column in the data
# Out:
#    coordinates                                 subjects  reward_max  \
# 0           []                [Violent Crime - Murders]           0
# 1           []                  [ViCAP Missing Persons]           0
# 2           []             [ViCAP Unidentified Persons]           0
# 3           []             [ViCAP Unidentified Persons]           0
# 4           []    [ViCAP Homicides and Sexual Assaults]           0
# 5           []                    [Seeking Information]           0
# 6           []                  [ViCAP Missing Persons]           0
# 7           []  [Seeking Information, Case of the Week]           0
# 8           []                      [Human Trafficking]           0
# 9           []              [Additional Violent Crimes]           0
# 10          []              [Additional Violent Crimes]           0
# 11          []     [Criminal Enterprise Investigations]           0
# 12          []              [Additional Violent Crimes]           0
# ...
