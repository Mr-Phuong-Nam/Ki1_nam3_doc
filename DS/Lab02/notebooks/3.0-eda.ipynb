# %% [markdown]
# <div style="text-align: center; background-color: #559cff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Lab 02 - Introduction To Data Science @ FIT-HCMUS, VNU-HCM 📌
# </div>

# %% [markdown]
# <div style="text-align: center; background-color: #b1d1ff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Stage 3.0 - Exploratory data analysis
# </div>

# %% [markdown]
# ## Import

# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# YOUR CODE HERE (OPTION) 
# If you need other libraries, you can import them here
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Exploring your data

# %% [markdown]
# ### Read cleaned data from file (0.25 points)

# %% [markdown]
# We can now use the cleaned dataset for analysis. Thus, we first read the CSV files we created in the previous pre-processing task.

# %%
# YOUR CODE HERE
cleaned_df = pd.read_csv('../data/processed/21120504_asia_processed.csv')
#raise NotImplementedError()

# %%
# TEST
cleaned_df.head()
# Out:
#    Total Population  Female Population  Male Population  Birth Rate  \
# 0        40099462.0         19844584.0       20254878.0      35.842
# 1        38972230.0         19279929.0       19692301.0      36.051
# 2        37769499.0         18679090.0       19090409.0      36.466
# 3        36686784.0         18136922.0       18549862.0      36.927
# 4        35643418.0         17614722.0       18028696.0      37.342
#
#    Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# 0       7.344                        9.0                   21.36864
# 1       7.113                        9.0                   18.48131
# 2       6.791                        9.0                   18.33941
# 3       6.981                        9.0                   18.12015
# 4       7.027                        9.0                   18.02644
#
#    Employment in Agriculture(%)  Female Employment in Agriculture(%)  \
# 0                     28.950359                            31.756573
# ...

# %% [markdown]
# ### Numerical analysis using descriptive statistics (0.25 points)

# %% [markdown]
# Descriptive statistics show the characteristics of numerical features. It shows us the information such as:
# - The mean (and you can go further with advanced techiques as Arithmetic mean, Geometric mean, Harmonic mean)
# - The median
# - The mode
# - Quantiles (Quartiles, Percentiles, Deciles, Crocodiles?)
# - Range and IQR (Interquartile Range) (you might find that its relation to box plots)
# - Variance and Standard deviation (std dev)
# - Coefficient of Variation
# - Skewness
# - Kurtosis
# - Standard Error (of the sample mean)
# - Moments
# - Covariance and Correlation
#
# Due the scope of this lab, you just need to use basic function of Pandas to calculate basic descriptive statistics information and give insights from it.

# %%
df_copy = cleaned_df.drop(['Year', 'Country'], axis='columns')

# YOUR CODE HERE
# raise NotImplementedError()
df_copy.describe()
# Out:
#        Total Population  Female Population  Male Population   Birth Rate  \
# count      1.269000e+03       1.269000e+03     1.269000e+03  1269.000000
# mean       8.974746e+07       4.410916e+07     4.563830e+07    20.700378
# std        2.538150e+08       1.234498e+08     1.303823e+08     7.833438
# min        2.582080e+05       1.249510e+05     1.332570e+05     5.100000
# 25%        4.360444e+06       2.115807e+06     2.282951e+06    15.051000
# 50%        1.811455e+07       8.986446e+06     8.916862e+06    19.841000
# 75%        6.127743e+07       3.044513e+07     3.079111e+07    24.649000
# max        1.412360e+09       6.912196e+08     7.265034e+08    52.073000
#
#         Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# count  1269.000000                1269.000000                1269.000000
# mean      6.343087                   8.881645                  21.368640
# std       2.718865                   1.782768                   7.894899
# ...

# %% [markdown]
# **TODO**: Give your observation here
#
# - Average of the population is 90 million,the female population is slightly smaller than the male population on average
#
# - The birth rate has a quite large range while the death rate range is much smaller
#
# - Compulsory education duration is typically 9 years.
#
# - Percentage of employment in argiculture is larger than that in industry.
#
# - Percentage of female employment is quite small.
#
# - Unemployment average rates is 5.97%.
#
# - GDP in USD has a wide range, show the difference in economic development between countries.
#
# - National income per capita has a similar range, with an average of about 1,185 USD.
#
# - Net income from abroad contributes a small proportion for most countries.
#
# - In asia, Obviously agricultural value added is quite high.
#
# - The Fossil Fuel Consumption is clearly higher than the Renewable Energy Consumption.
#
# - Female expectancy is higher than male expectancy.
#
# - School enrollment rates in primary and tertiary education exhibit variations.

# %% [markdown]
# ### Describe the correlation between features in the dataset (0.75 points)

# %% [markdown]
# Considering the available features within the training dataset, we want to identify and analyse the relationships between them, and then determine which features within the dataset significantly contribute to our solution goal. By using calculation and visualisation, Python allows us to create a correlation matrix, which is a table that represents the correlation coefficients between different variables.

# %% [markdown]
# Now let's make a correlation matrix, then visualize it, and describe what insights you observed?

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION) 
def draw_correation_heatmap(df, ax=None,labels_col=True):
    corr = df.corr()
    # remove upper triangle which is duplicated
    mask = np.triu(np.ones_like(corr, dtype=bool))
    sns.heatmap(corr, mask = mask, linewidths=0.5, cmap='coolwarm', vmax=1, vmin=-1, ax=ax, yticklabels=labels_col)

# %%
# YOUR CODE HERE
# create a copy
df_copy = cleaned_df.copy()

# drop columns
df_copy.drop(['Year', 'Country'], axis='columns', inplace=True)

# create correlation matrix
plt.figure(figsize=(10, 7))
draw_correation_heatmap(df_copy)
plt.title('Correlation Heatmap of all Countries')
plt.show()
#raise NotImplementedError()

# %% [markdown]
# Some attributes seem to be correlated with each other, such as:
# - Total population, female and male population
# - GDP has a slight correlation with the population
# - But agricultural value added has a strong correlation with the population
# - GPD depends a lot on the agricultural value added
# - Employment in agriculture has a slight correlation with renewable energy consumption and slight negative correlation with fossil fuel consumption.
# - Birth and death rates are slightly negatively correlated with life expectancy
# - Life expectancy is negatively correlated with the percentage of employment in agriculture

# %% [markdown]
# **Question 01**: How does the correlation between features change in the top 10 countries with the LARGEST population?
#
# When we have an answer for this question, we might see how features interaction with each other when the conutry population is large.

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION)
# Choose top 10 countries with the largest population in 2019
top10_highest_population2019 = cleaned_df[cleaned_df['Year'] == 2019].sort_values(by='Total Population', ascending=False).head(10)
top10_highest_population2019[['Country', 'Total Population', 'Year']].reset_index(drop=True)
# Out:
#               Country  Total Population  Year
# 0               China      1.407745e+09  2019
# 1               India      1.383112e+09  2019
# 2           Indonesia      2.695829e+08  2019
# 3            Pakistan      2.232933e+08  2019
# 4          Bangladesh      1.655162e+08  2019
# 5  Russian Federation      1.444063e+08  2019
# 6               Japan      1.266330e+08  2019
# 7         Philippines      1.103808e+08  2019
# 8             Vietnam      9.577672e+07  2019
# 9  Iran, Islamic Rep.      8.656420e+07  2019

# %%
# YOUR CODE HERE
# Create two sub heatmaps
fig, ax = plt.subplots(1, 2, figsize=(20, 7))

# Draw two heatmaps for easy comparison
draw_correation_heatmap(df_copy, ax[0])
ax[0].set_title('Correlation Heatmap of All Countries')

draw_correation_heatmap(top10_highest_population2019.drop(["Year", "Country"], axis=1), ax[1], labels_col=False)
ax[1].set_title('Correlation Heatmap of Top 10 Countries with Highest Population in 2019')

plt.show()

# %% [markdown]
# Some attributes increase their effect when the population is large, such as:
# - Birth rate increases its effect on life expectancy, education and energy consumption.
# - The same for employment in agriculture and fossil fuel consumption.
#
# `We can see in the top countries, education seems to be more and more important.`

# %% [markdown]
# **YOUR ANSWER**

# %% [markdown]
# **Question 02**: How does the correlation between features change in the top 10 countries with the SMALLEST population?
#
# When we have an answer for this question, we might see how features interaction with each other when the conutry population is small.

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION) 
# Choose top 10 countries with the smallest population in 2019
top10_lowest_population2019 = cleaned_df[cleaned_df['Year'] == 2019].sort_values(by='Total Population', ascending=True).head(10)
top10_lowest_population2019[['Country', 'Total Population', 'Year']].reset_index(drop=True)
# Out:
#              Country  Total Population  Year
# 0  Brunei Darussalam          438048.0  2019
# 1           Maldives          504508.0  2019
# 2             Bhutan          767459.0  2019
# 3             Cyprus         1228836.0  2019
# 4            Bahrain         1494188.0  2019
# 5              Qatar         2807235.0  2019
# 6            Armenia         2820602.0  2019
# 7           Mongolia         3232430.0  2019
# 8            Georgia         3720161.0  2019
# 9             Kuwait         4441100.0  2019

# %%
# YOUR CODE HERE
# Create two sub heatmaps
fig, ax = plt.subplots(1, 2, figsize=(20, 7))

draw_correation_heatmap(df_copy, ax[0])
ax[0].set_title('Correlation Heatmap of All Countries')

draw_correation_heatmap(top10_lowest_population2019.drop(["Year", "Country"], axis=1), ax[1], labels_col=False)
ax[1].set_title('Correlation Heatmap of Top 10 Countries with Lowest Population in 2019')

plt.show()

# %% [markdown]
# In low population countries:
# - Population has a strong effecting.
# - All the other attributes increase their effect to others.

# %% [markdown]
# **YOUR ANSWER**
#
# Example: Is that possible to drop any features that have less effect?
# - Total Population, Female Population, Male Population: we may choose to remove one of these population-related features.
# - Primary completion rate: we can remove this feature because it has less meaningful and correlate with Primary Enrollment Rate.

# %% [markdown]
# ## Making a question? (1.25 points)

# %% [markdown]
# After exploring the data, we have a better understanding of the data. Now let's see what questions can be answered with this data.
#
# **A possible question is:** What is the population situation of the countries on the continent today?
#
# **Answering this question will** help us to see the current population status and predictions about the future development of the labor force of the countries on the continent are under consideration.
#
# **How we answer this question**: we will consider the Average Birth Rate and Death Rate for countries across all the year.

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION) 
avg_df_by_country = cleaned_df.groupby(['Country']).mean().reset_index()[["Birth Rate", "Death Rate", "Country"]]
avg_df_by_country.head()
# Out:
#    Birth Rate  Death Rate      Country
# 0   43.412778    9.552741  Afghanistan
# 1   13.628407    9.286741      Armenia
# 2   16.029630    6.051852   Azerbaijan
# 3   17.663407    2.282222      Bahrain
# 4   23.682111    6.546111   Bangladesh

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# Step 01: construct Average Birth Rate dataframe for each country.

# %%
# YOUR CODE HERE

# Create a new dataframe
avg_birthrate_df = pd.DataFrame()
avg_birthrate_df = avg_df_by_country.drop(['Death Rate'], axis='columns').reset_index(drop=True)

avg_birthrate_df.head()

#raise NotImplementedError()
# Out:
#    Birth Rate      Country
# 0   43.412778  Afghanistan
# 1   13.628407      Armenia
# 2   16.029630   Azerbaijan
# 3   17.663407      Bahrain
# 4   23.682111   Bangladesh

# %%
# See the range of birth rate
avg_birthrate_df.describe()
# Out:
#        Birth Rate
# count   47.000000
# mean    20.700378
# std      7.280333
# min      8.474074
# 25%     15.550037
# 50%     19.915852
# 75%     24.209370
# max     43.412778

# %%
# You can just construct plotting for top countries
# YOUR CODE HERE (OPTION)

# Draw a histogram of average birth rates
plt.figure(figsize=(7, 5))
sns.histplot(data=avg_birthrate_df, x="Birth Rate", bins=10)
plt.title('Histogram of Average Birth Rate')
plt.show()

# %% [markdown]
# Step 02: construct Average Death Rate dataframe for each country.

# %%
# Create a new dataframe
avg_deathrate_df = pd.DataFrame()
avg_deathrate_df = avg_df_by_country.drop(['Birth Rate'], axis='columns').reset_index(drop=True)

avg_deathrate_df.head()

# YOUR CODE HERE
# raise NotImplementedError()
# Out:
#    Death Rate      Country
# 0    9.552741  Afghanistan
# 1    9.286741      Armenia
# 2    6.051852   Azerbaijan
# 3    2.282222      Bahrain
# 4    6.546111   Bangladesh

# %%
# See the range of death rate
avg_deathrate_df.describe()
# Out:
#        Death Rate
# count   47.000000
# mean     6.343087
# std      2.592796
# min      1.556519
# 25%      4.886130
# 50%      6.446889
# 75%      7.602000
# max     14.311111

# %%
# You can just construct plotting for top countries
# YOUR CODE HERE
# raise NotImplementedError()

#Draw a histogram of death rate
plt.figure(figsize=(7, 5))
sns.histplot(data=avg_deathrate_df, x="Death Rate", bins=10)
plt.title('Histogram of Average Death Rate')
plt.show()

# %%
# Calculate the average population growth rate
avg_df_by_country['Population Growth Rate'] = avg_df_by_country['Birth Rate'] - avg_df_by_country['Death Rate']
avg_df_by_country.describe()
# Out:
#        Birth Rate  Death Rate  Population Growth Rate
# count   47.000000   47.000000               47.000000
# mean    20.700378    6.343087               14.357292
# std      7.280333    2.592796                7.711356
# min      8.474074    1.556519               -3.533333
# 25%     15.550037    4.886130               10.244259
# 50%     19.915852    6.446889               14.265556
# 75%     24.209370    7.602000               17.895148
# max     43.412778   14.311111               33.860037

# %%
# Draw a histogram of population growth rate
plt.figure(figsize=(7, 5))
sns.histplot(data=avg_df_by_country, x="Population Growth Rate", bins=10)
plt.title('Histogram of Average Population Growth Rate')
plt.show()

# %%
avg_df_by_year = (cleaned_df.drop(['Country'], axis=1)
                            .groupby(['Year']).mean()
                            .reset_index()
                            [["Birth Rate", "Death Rate", "Year"]])
avg_df_by_year['Population Growth Rate'] = avg_df_by_year['Birth Rate'] - avg_df_by_year['Death Rate']
avg_df_by_year.describe()
# Out:
#        Birth Rate  Death Rate         Year  Population Growth Rate
# count   27.000000   27.000000    27.000000               27.000000
# mean    20.700378    6.343087  2008.000000               14.357292
# std      2.251494    0.403618     7.937254                1.981498
# min     16.781340    5.890234  1995.000000                9.945830
# 25%     19.580809    5.979596  2001.500000               13.630926
# 50%     20.603894    6.276872  2008.000000               14.375745
# 75%     21.684947    6.618872  2014.500000               15.151085
# max     25.826128    7.250511  2021.000000               18.575617

# %%
# Draw a line plot of average birth rate, death rate and population growth rate by year
plt.figure(figsize=(10, 5))

sns.lineplot(data=avg_df_by_year, x="Year", y="Birth Rate", label="Birth Rate")
sns.lineplot(data=avg_df_by_year, x="Year", y="Death Rate", label="Death Rate")
sns.lineplot(data=avg_df_by_year, x="Year", y="Population Growth Rate", label="Population Growth Rate")

plt.title('Line Plot of Average Birth Rate, Death Rate and Population Growth Rate by Year')
plt.ylabel('Rate per 1000 population')
plt.show()

# %% [markdown]
# **TODO**: Give your obervation here
#
# - Almost average birth rates in continents are in range 10-30 per 1000 people.
# - Almost average death rates in continents are in range 2-10 per 1000 people.
# - Almost average population growth rates in continents are in range 5-25 per 1000 people.
#
# The population in Asia grow quite fast. The population growth rate in Asia tends to decrease by time. Strongly decrease in 2021 because of the covid-19.
#
# I think this growth rate is still quite high and we should decrease it in the future. But it still depends on the situation of each country.

# %% [markdown]
# ## Making your own question 01? (1.5 points)

# %% [markdown]
# **YOUR ANSWER HERE**
#
# `What is the situation of the life expectancy of the countries on the continent today? Which countries have the highest life expectancy and which countries have the lowest life expectancy?`

# %% [markdown]
# ### Pre-processing

# %%
avg_life_expectancy_df = cleaned_df.drop(["Country"], axis=1).groupby("Year").mean().reset_index()
avg_life_expectancy_df = avg_life_expectancy_df[["Male life expectancy", "Female life expectancy", "Year"]]
avg_life_expectancy_df.head()
# Out:
#    Male life expectancy  Female life expectancy  Year
# 0             64.671596               69.792064  1995
# 1             64.995213               70.115936  1996
# 2             65.319319               70.469936  1997
# 3             65.667404               70.816191  1998
# 4             66.127532               71.182234  1999

# %% [markdown]
# ### Analyzing to get the answer

# %%
# Draw line chart for average life expectancy by year
plt.figure(figsize=(10, 5))
sns.lineplot(avg_life_expectancy_df, y="Male life expectancy", x="Year")
sns.lineplot(avg_life_expectancy_df, y="Female life expectancy", x="Year")
plt.title('Line Plot of Average Life Expectancy by Year')
plt.show()

# %% [markdown]
# `By years, the life expectancy tends to increase beacause of the development of the medical industry. But in 2021, the life expectancy decreases because of the covid-19.`

# %%
sorted_female_life_expectancy_df = cleaned_df[cleaned_df["Year"] == 2019].sort_values(by="Female life expectancy", ascending=False).reset_index(drop=True)
sorted_male_life_expectancy_df = cleaned_df[cleaned_df["Year"] == 2019].sort_values(by="Male life expectancy", ascending=False).reset_index(drop=True)

# %%
top5_highest_female_life_expectancy = sorted_female_life_expectancy_df.head(5)
top5_lowest_female_life_expectancy = sorted_female_life_expectancy_df.tail(5)

top5_highest_male_life_expectancy = sorted_male_life_expectancy_df.head(5)
top5_lowest_male_life_expectancy = sorted_male_life_expectancy_df.tail(5)

# %%
# create subplots
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# plot top 5 highest female life expectancy
sns.barplot(x='Female life expectancy', y='Country', data=top5_highest_female_life_expectancy, ax=axes[0, 0])
axes[0, 0].set_title('Top 5 Countries with Highest Female Life Expectancy')

# plot top 5 lowest female life expectancy
sns.barplot(x='Female life expectancy', y='Country', data=top5_lowest_female_life_expectancy, ax=axes[0, 1])
axes[0, 1].set_title('Top 5 Countries with Lowest Female Life Expectancy')

# plot top 5 highest male life expectancy
sns.barplot(x='Male life expectancy', y='Country', data=top5_highest_male_life_expectancy, ax=axes[1, 0])
axes[1, 0].set_title('Top 5 Countries with Highest Male Life Expectancy')

# plot top 5 lowest male life expectancy
sns.barplot(x='Male life expectancy', y='Country', data=top5_lowest_male_life_expectancy, ax=axes[1, 1])
axes[1, 1].set_title('Top 5 Countries with Lowest Male Life Expectancy')

plt.tight_layout()
plt.show()

# %% [markdown]
# `The safest place to live in Asia is Japan and the most dangerous place to live in Asia is Afghanistan.`

# %% [markdown]
# ## Making your own question 02? (1.5 points)

# %% [markdown]
# **YOUR ANSWER HERE**
#
# `What is the situation of the economy in the countries on the continent today? What makes the top countries' economy develop?`
#
# **Answering this question will** help us to see the current economy status and propose some solutions to improve the economy.
#
# **How we answer this question**: we will consider the total population and GDP in USD for countries in 2021. The we consider some features that may affect the economic development of some top countries.

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION) 
df_2021 = cleaned_df[cleaned_df['Year'] == 2021].reset_index(drop=True)
df_2021.head()
# Out:
#    Total Population  Female Population  Male Population  Birth Rate  \
# 0        40099462.0         19844584.0       20254878.0      35.842
# 1         2790974.0          1534476.0        1256498.0      12.049
# 2        10137750.0          5135000.0        5002750.0      11.100
# 3         1463265.0           554616.0         908649.0      11.926
# 4       169356251.0         85358163.0       83998088.0      17.821
#
#    Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# 0       7.344                        9.0                   21.36864
# 1      13.007                       12.0                   17.53141
# 2       7.600                       10.0                   15.44495
# 3       2.479                        9.0                   34.92438
# 4       5.680                        5.0                   21.71396
#
#    Employment in Agriculture(%)  Female Employment in Agriculture(%)  \
# 0                     28.950359                            31.756573
# ...

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# Get top 10 countries with the highest GDP in 2021.

# %%
top10_highest_GDP_2021 = df_2021.sort_values(by='GDP in USD', ascending=False).head(10)
top10_highest_GDP_2021[['Country', 'GDP in USD']].reset_index(drop=True)
# Out:
#               Country    GDP in USD
# 0               China  1.782046e+13
# 1               Japan  5.005537e+12
# 2               India  3.150307e+12
# 3  Russian Federation  1.836892e+12
# 4         Korea, Rep.  1.810956e+12
# 5           Indonesia  1.186505e+12
# 6        Saudi Arabia  8.685859e+11
# 7              Turkey  8.190345e+11
# 8            Thailand  5.055681e+11
# 9              Israel  4.885265e+11

# %%
# YOUR CODE HERE
# Draw a bar plot of top 20 countries with the highest GDP in 2021 with their national flags in the background
plt.figure(figsize=(15, 7))
sns.barplot(data=top10_highest_GDP_2021[:20], y="Country", x="GDP in USD")
plt.title('Bar Plot of Top 20 Countries with the Highest GDP in 2021')

plt.show()

# %% [markdown]
# Get top 10 countries with the highest GDP per capita in 2021.

# %%
df_2021["GPD per capital"] = df_2021["GDP in USD"] / df_2021["Total Population"]

# %%
top10_highest_GPDperCapita_2021 = df_2021.sort_values(by='GPD per capital', ascending=False).head(10)
top10_highest_GPDperCapita_2021[['Country', 'GPD per capital']].reset_index(drop=True)
# Out:
#                 Country  GPD per capital
# 0             Singapore     77710.069957
# 1          Turkmenistan     67594.051864
# 2                 Qatar     66838.327641
# 3                Israel     52166.812165
# 4  United Arab Emirates     44315.554184
# 5                 Japan     39827.126768
# 6           Korea, Rep.     34997.781643
# 7                Kuwait     32186.765408
# 8     Brunei Darussalam     31448.913608
# 9               Bahrain     26860.072502

# %%
# Draw a bar plot
plt.figure(figsize=(15, 7))
sns.barplot(data=top10_highest_GPDperCapita_2021, y="Country", x="GPD per capital")
plt.title('Bar Plot of Top 10 Countries with the Highest GPD per Capita in 2021')
plt.show()

# %% [markdown]
# We can see:
# - China has the highest GDP
# - Singapore has the highest GDP per capita
#
# `What did the top countries do to develop their economy?`

# %% [markdown]
# We will add some features that may affect the economic development of China and Singapore.

# %%
import requests
BASE_URL = 'http://api.worldbank.org/v2/'

def get_another_indicator(country_code, indicator_code,indicator_name, start_year, end_year, per_page=100, format='json'):
    url = BASE_URL+'countries/' + country_code.lower() + '/indicators/' + indicator_code.lower()
    # gửi request với các tham số mặc định bằng resquests module
    params = {'format': format,
                'per_page': str(per_page),
                'date': str(start_year) + ":" + str(end_year)}
    response = requests.get(url, params=params)
    dataLst = []
    # Xác thực mã trạng thái phản hồi
    # API trả về status_code 200 ngay cả đối với các thông báo lỗi,
    # tuy nhiên, nội dung phản hồi chứa một trường có tên là "thông báo" bao gồm các chi tiết về lỗi
    # kiểm tra xem tin nhắn có xuất hiện trong phản hồi hay không
    if response.status_code == 200 and ("message" not in response.json()[0].keys()):
        # print("Successfully got data for: " + str(featureMap[indicator]))

        # danh sách các giá trị cho một đặc trưng
        indicatorVals = []

        # phản hồi là một mảng chứa hai mảng - [[{page: 1, ...}], [{year: 2018, SP.POP.TOTL: 123455}, ...]]
        # do đó chúng ta kiểm tra xem độ dài của phản hồi có > 1 hay không
        if len(response.json()) > 1:

            # nếu có, lặp lại từng đối tượng trong phản hồi
            # mỗi đối tượng cho một giá trị duy nhất cho mỗi năm
            for obj in response.json()[1]:

                # Kiểm tra giá trị rỗng
                if (obj['value'] == "") or (obj['value'] is None):
                    indicatorVals.append('None')
                else:
                    # nếu có một giá trị, hãy thêm nó vào danh sách các giá trị chỉ báo indicatorVals
                    indicatorVals.append(float(obj['value']))

            dataLst.append(indicatorVals)

        else:
            # In thông báo lỗi nếu lệnh gọi API không thành công
            print("Error in Loading the data. Status Code: " +
                    str(response.status_code))

    # Khi đã có được tất cả các đặc trưng, ta thêm các giá trị cho "Năm"
    # API trả về các giá trị indicator từ năm gần đây nhất. Do đó, chúng tôi tạo một danh sách các năm ngược lại
    dataLst.append([year for year in range(
        int(end_year), int(start_year)-1, -1)])
    df = pd.DataFrame(dataLst).T
    df.columns = [indicator_name, 'Year']
    return df

# %%
indicators = {'NV.IND.TOTL.ZS' : 'Industry (including construction), value added (% of GDP)',
              'NE.EXP.GNFS.ZS' : 'Exports of goods and services (% of GDP)',
              'NE.IMP.GNFS.ZS' : 'Imports of goods and services (% of GDP)',
              'NV.AGR.TOTL.ZS' : 'Agriculture, forestry, and fishing, value added (% of GDP)'}

# %% [markdown]
# ### For China
# We want to see the percentage of some main economic components in China like:
# - Agriculture
# - Industry
# - Import
# - Export

# %%
country_code = 'CN'
china_economy_df = pd.DataFrame()

for indicator_code, indicator_name in indicators.items():
    df = get_another_indicator(country_code, indicator_code, indicator_name, 1995, 2021)
    china_economy_df = pd.concat([china_economy_df, df], axis=1)

# Remove year duplicated column
china_economy_df = china_economy_df.loc[:,~china_economy_df.columns.duplicated()]

# Move year column to the last column
china_economy_df = china_economy_df[['Industry (including construction), value added (% of GDP)', 'Exports of goods and services (% of GDP)', 'Imports of goods and services (% of GDP)', 'Agriculture, forestry, and fishing, value added (% of GDP)', 'Year']]

china_economy_df.head()
# Out:
#    Industry (including construction), value added (% of GDP)  \
# 0                                          39.290773
# 1                                          37.842822
# 2                                          38.587405
# 3                                          39.687012
# 4                                          39.851698
#
#    Exports of goods and services (% of GDP)  \
# 0                                 19.943973
# 1                                 18.586139
# 2                                 18.409992
# 3                                 19.112104
# 4                                 19.692277
#
#    Imports of goods and services (% of GDP)  \
# 0                                 17.358017
# 1                                 16.168157
# 2                                 17.480104
# 3                                 18.453681
# 4                                 17.940136
#
#    Agriculture, forestry, and fishing, value added (% of GDP)    Year
# ...

# %%
# Draw a stacked area chart
plt.figure(figsize=(15, 7))
plt.stackplot(china_economy_df["Year"], china_economy_df["Industry (including construction), value added (% of GDP)"], china_economy_df["Exports of goods and services (% of GDP)"], china_economy_df["Imports of goods and services (% of GDP)"],china_economy_df["Agriculture, forestry, and fishing, value added (% of GDP)"], labels=['Industry', 'Exports', 'Imports', 'Agriculture'])
plt.legend()
plt.show()

# %% [markdown]
# As we can see:
# - China has a very high percentage of industry. And it remains stable over the years.
# - Export and import increase over the years.
# - Agriculture has a very low percentage. And it decreases over the years.
#
# So we can see that China primarily focuses on developing its industries and services, decreasing agriculture.

# %% [markdown]
# ### For Singapore

# %%
country_code = 'SG'
singapore_economy_df = pd.DataFrame()

for indicator_code, indicator_name in indicators.items():
    df = get_another_indicator(country_code, indicator_code, indicator_name, 1995, 2021)
    singapore_economy_df = pd.concat([singapore_economy_df, df], axis=1)

# Remove year duplicated column
singapore_economy_df = singapore_economy_df.loc[:,~singapore_economy_df.columns.duplicated()]

# Move year column to the last column
singapore_economy_df = singapore_economy_df[['Industry (including construction), value added (% of GDP)', 'Exports of goods and services (% of GDP)', 'Imports of goods and services (% of GDP)', 'Agriculture, forestry, and fishing, value added (% of GDP)', 'Year']]
singapore_economy_df.head()
# Out:
#    Industry (including construction), value added (% of GDP)  \
# 0                                          24.364089
# 1                                          23.338726
# 2                                          24.047788
# 3                                          25.386308
# 4                                          23.512043
#
#    Exports of goods and services (% of GDP)  \
# 0                                184.302420
# 1                                181.988603
# 2                                175.594437
# 3                                177.350437
# 4                                171.564620
#
#    Imports of goods and services (% of GDP)  \
# 0                                149.037189
# 1                                150.785223
# 2                                146.109060
# 3                                147.846922
# 4                                144.912950
#
#    Agriculture, forestry, and fishing, value added (% of GDP)    Year
# ...

# %%
# Draw a stacked area chart
plt.figure(figsize=(15, 5))
plt.stackplot(singapore_economy_df["Year"], singapore_economy_df["Industry (including construction), value added (% of GDP)"], singapore_economy_df["Exports of goods and services (% of GDP)"], singapore_economy_df["Imports of goods and services (% of GDP)"],singapore_economy_df["Agriculture, forestry, and fishing, value added (% of GDP)"], labels=['Industry', 'Exports', 'Imports', 'Agriculture'])
plt.legend()
plt.show()

# %% [markdown]
# As we can see:
# - Singapore almost has no agriculture.
# - Service is the main economic component in Singapore.
# - Industry has a quite low percentage.
#
# So we can see that Singapore primarily focuses on developing its services, It brings a lot of revenue for Singapore and make it GDP per capita is the highest in the asia.

# %% [markdown]
# `Most developed countries rely on increasing the proportion of industry and service while reducing the proportion of agriculture in their economy.`
